# %%
import bokeh
bokeh.__version__
# Out:
# '0.12.7'

# %%
from bokeh.io import output_notebook, show, output_file
from bokeh.plotting import figure, show, save
from bokeh.models import HoverTool
output_notebook()
from bokeh.layouts import gridplot
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="eb0255c2-749e-4ea2-b3c9-ea79f4b21891">Loading BokehJS ...</span>
#     </div>

# %%
import pandas as pd
AAPL = pd.read_csv('C:\\Users\\Arunima Chaudhary\\Downloads\\indicator CDIAC carbon_dioxide_total_emissions.csv')
#AAPL = pd.read_csv('indicator CDIAC carbon_dioxide_total_emissions.csv')

# %%
df2=AAPL.set_index("CO2 emission total")
df2
# Out:
#                            1751  1755  1760  1765  1770  1771  1772  1773  \
# CO2 emission total
# Abkhazia                    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan                 NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Akrotiri and Dhekelia       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Algeria                     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# American Samoa              NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Andorra                     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Angola                      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Anguilla                    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Antigua and Barbuda         NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Argentina                   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...

# %%
India = df2.loc["India","1990":"2011"]
China = df2.loc["China","1990":"2011"]
USA = df2.loc["United States","1990":"2011"]
Russia = df2.loc["Russia","1990":"2011"]
Japan = df2.loc["Japan","1990":"2011"]
Germany = df2.loc["Germany","1990":"2011"]
Iran = df2.loc["Iran","1990":"2011"]
SKorea = df2.loc["South Korea","1990":"2011"]
Canada = df2.loc["Canada","1990":"2011"]
SArabia = df2.loc["Saudi Arabia","1990":"2011"]

# %%
Ch = pd.DataFrame({'year':China.index, 'emission':China.values})
In = pd.DataFrame({'year':India.index, 'emission':India.values})
US = pd.DataFrame({'year':USA.index, 'emission':USA.values})
Ru = pd.DataFrame({'year':Russia.index, 'emission':Russia.values})
Ja = pd.DataFrame({'year':Japan.index, 'emission':Japan.values})
Ge = pd.DataFrame({'year':Germany.index, 'emission':Germany.values})
Ir = pd.DataFrame({'year':Iran.index, 'emission':Iran.values})
SK = pd.DataFrame({'year':SKorea.index, 'emission':SKorea.values})
Ca = pd.DataFrame({'year':Canada.index, 'emission':Canada.values})
SA = pd.DataFrame({'year':SArabia.index, 'emission':SArabia.values})

# %%
from bokeh.models import ColumnDataSource
from bokeh.models import HoverTool
from bokeh.models import NumeralTickFormatter

# %%
ds = ColumnDataSource(data=dict(x=In[In.columns[1]], 
                                y1=Ch[Ch.columns[0]], 
                                y2=US[US.columns[0]], 
                                y3=Ru[Ru.columns[0]],
                                y4=Ru[Ru.columns[0]],
                                y5=Ru[Ru.columns[0]],
                                y6=Ru[Ru.columns[0]],
                                y7=Ru[Ru.columns[0]],
                                y8=Ru[Ru.columns[0]],
                                y9=Ru[Ru.columns[0]],
                                y10=Ru[Ru.columns[0]],
                               ))
max( ds.data['x'] )
# Out:
# '2011'

# %%
#China
#ds = ColumnDataSource(Ch)
_tools_to_show = 'box_zoom,pan,save,hover,reset,tap,wheel_zoom'
p1 = figure(plot_width=500, plot_height=300, title="1.China", tools=_tools_to_show)
p1.yaxis.axis_label ='CO2 Emission in 500 metric tons'
p1.xaxis.axis_label ='Year'
p1.line('x', 'y1', source=ds)
p1.circle('x', 'y1', source=ds)

hover = p1.select(dict(type=HoverTool))
hover.tooltips = [("Year", "@x"),  ("Emission(in 500 metric tons)", "@y1{int}")]
hover.mode = 'mouse'

p1.yaxis.formatter=NumeralTickFormatter(format="0,0")



#USA
#ds = ColumnDataSource(US)
p2 = figure(plot_width=500, plot_height=300, title="2.USA", tools=_tools_to_show, x_range=p1.x_range)
p2.yaxis.axis_label ='CO2 Emission in 500 metric tons'
p2.xaxis.axis_label ='Year'
p2.line('x', 'y2', source=ds)
p2.circle('x', 'y2', source=ds)

hover = p2.select(dict(type=HoverTool))
hover.tooltips = [("Year", "@x"),  ("Emission(in 500 metric tons)", "@y2{int}")]
hover.mode = 'mouse'

p2.yaxis.formatter=NumeralTickFormatter(format="0,0")


#Russia
#ds = ColumnDataSource(Ru)
p3 = figure(plot_width=500, plot_height=300, title="3.Russia", tools=_tools_to_show, x_range=p1.x_range)
p3.yaxis.axis_label ='CO2 Emission in 500 metric tons'
p3.xaxis.axis_label ='Year'
p3.line('x', 'y3', source=ds)
p3.circle('x', 'y3', source=ds)

hover = p3.select(dict(type=HoverTool))
hover.tooltips = [("Year", "@x"),  ("Emission(in 500 metric tons)", "@y3{int}")]
hover.mode = 'mouse'

p3.yaxis.formatter=NumeralTickFormatter(format="0,0")


#India
#ds = ColumnDataSource(In)
p4 = figure(plot_width=500, plot_height=300, title="4.India", tools=_tools_to_show, x_range=p1.x_range)
p4.yaxis.axis_label ='CO2 Emission in 500 metric tons'
p4.xaxis.axis_label ='Year'
p4.line('x', 'y4', source=ds)
p4.circle('x', 'y4', source=ds)

hover = p4.select(dict(type=HoverTool))
hover.tooltips = [("Year", "@x"),  ("Emission(in 500 metric tons)", "@y4{int}")]
hover.mode = 'mouse'

p4.yaxis.formatter=NumeralTickFormatter(format="0,0")

#Japan
#ds = ColumnDataSource(Ja)
p5 = figure(plot_width=500, plot_height=300, title="5.Japan", tools=_tools_to_show, x_range=p1.x_range)
p5.yaxis.axis_label ='CO2 Emission in 500 metric tons'
p5.xaxis.axis_label ='Year'
p5.line('x', 'y5', source=ds)
p5.circle('x', 'y5', source=ds)

hover = p5.select(dict(type=HoverTool))
hover.tooltips = [("Year", "@x"),  ("Emission(in 500 metric tons)", "@y5{int}")]
hover.mode = 'mouse'

p5.yaxis.formatter=NumeralTickFormatter(format="0,0")


#Germany
#ds = ColumnDataSource(Ge)
p6 = figure(plot_width=500, plot_height=300, title="6.Germany", tools=_tools_to_show, x_range=p1.x_range)
p6.yaxis.axis_label ='CO2 Emission in 500 metric tons'
p6.xaxis.axis_label ='Year'
p6.line('x', 'y6', source=ds)
p6.circle('x', 'y6', source=ds)

hover = p6.select(dict(type=HoverTool))
hover.tooltips = [("Year", "@x"),  ("Emission(in 500 metric tons)", "@y6{int}")]
hover.mode = 'mouse'

p6.yaxis.formatter=NumeralTickFormatter(format="0,0")


#Iran
#ds = ColumnDataSource(Ir)
p7 = figure(plot_width=500, plot_height=300, title="7.Iran", tools=_tools_to_show, x_range=p1.x_range)
p7.yaxis.axis_label ='CO2 Emission in 500 metric tons'
p7.xaxis.axis_label ='Year'
p7.line('x', 'y7', source=ds)
p7.circle('x', 'y7', source=ds)

hover = p7.select(dict(type=HoverTool))
hover.tooltips = [("Year", "@x"),  ("Emission(in 500 metric tons)", "@y7{int}")]
hover.mode = 'mouse'

p7.yaxis.formatter=NumeralTickFormatter(format="0,0")


#South Korea
#ds = ColumnDataSource(SK)
p8 = figure(plot_width=500, plot_height=300, title="8.South Korea", tools=_tools_to_show, x_range=p1.x_range)
p8.yaxis.axis_label ='CO2 Emission in 500 metric tons'
p8.xaxis.axis_label ='Year'
p8.line('x', 'y8', source=ds)
p8.circle('x', 'y8', source=ds)

hover = p8.select(dict(type=HoverTool))
hover.tooltips = [("Year", "@x"),  ("Emission(in 500 metric tons)", "@y8{int}")]
hover.mode = 'mouse'

p8.yaxis.formatter=NumeralTickFormatter(format="0,0")


#Canada
#ds = ColumnDataSource(Ca)
p9 = figure(plot_width=500, plot_height=300, title="9.Canada", tools=_tools_to_show, x_range=p1.x_range)
p9.yaxis.axis_label ='CO2 Emission in 500 metric tons'
p9.xaxis.axis_label ='Year'
p9.line('x', 'y9', source=ds)
p9.circle('x', 'y9', source=ds)

hover = p9.select(dict(type=HoverTool))
hover.tooltips = [("Year", "@x"),  ("Emission(in 500 metric tons)", "@y10{int}")]
hover.mode = 'mouse'

p9.yaxis.formatter=NumeralTickFormatter(format="0,0")




#Saudi Arabia
#ds = ColumnDataSource(SA)
p10 = figure(plot_width=500, plot_height=300, title="10.Saudi Arabia", tools=_tools_to_show, x_range=p1.x_range)
p10.yaxis.axis_label ='CO2 Emission in 500 metric tons'
p10.xaxis.axis_label ='Year'
p10.line('x', 'y10', source=ds)
p10.circle('x', 'y10', source=ds)

hover = p10.select(dict(type=HoverTool))
hover.tooltips = [("Year", "@x"),  ("Emission(in 500 metric tons)", "@y10{int}")]
hover.mode = 'mouse'

p10.yaxis.formatter=NumeralTickFormatter(format="0,0")

s = gridplot([[p1, p2], [p3, p4], [p5 ,p6], [p7, p8], [p9, p10]])

save(s,'arunima.html')
# Out:
# C:\Users\Arunima Chaudhary\Anaconda3\lib\site-packages\bokeh\io.py:527: UserWarning: save() called but no resources were supplied and output_file(...) was never called, defaulting to resources.CDN
#   warnings.warn("save() called but no resources were supplied and output_file(...) was never called, defaulting to resources.CDN")
# C:\Users\Arunima Chaudhary\Anaconda3\lib\site-packages\bokeh\io.py:537: UserWarning: save() called but no title was supplied and output_file(...) was never called, using default title 'Bokeh Plot'
#   warnings.warn("save() called but no title was supplied and output_file(...) was never called, using default title 'Bokeh Plot'")
# 'C:\\Users\\Arunima Chaudhary\\arunima.html'
